# %% [markdown]
# # Simple MNIST Convnet

# %% [markdown]
# ## Setup

# %%
# Libraries.
import numpy as np
import keras
from keras import layers
import cv2
from keras.models import load_model
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ## Prepare the data

# %%
# Model / data parameters.
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets.
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the model

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        16,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,826 (136.04 KB)
#  Trainable params: 34,826 (136.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train the model

# %%
batch_size = 64
epochs = 50

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9163 - loss: 0.2764 - val_accuracy: 0.9832 - val_loss: 0.0683
# Epoch 2/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9713 - loss: 0.0923 - val_accuracy: 0.9883 - val_loss: 0.0457
# Epoch 3/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9783 - loss: 0.0703 - val_accuracy: 0.9885 - val_loss: 0.0380
# Epoch 4/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9811 - loss: 0.0605 - val_accuracy: 0.9905 - val_loss: 0.0343
# Epoch 5/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9843 - loss: 0.0517 - val_accuracy: 0.9918 - val_loss: 0.0315
# Epoch 6/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9846 - loss: 0.0493 - val_accuracy: 0.9898 - val_loss: 0.0373
# Epoch 7/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9858 - loss: 0.0442 - val_accuracy: 0.9910 - val_loss: 0.0325
# Epoch 8/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9868 - loss: 0.0420 - val_accuracy: 0.9925 - val_loss: 0.0287
# Epoch 9/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9884 - loss: 0.0373 - val_accuracy: 0.9920 - val_loss: 0.0302
# Epoch 10/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9889 - loss: 0.0339 - val_accuracy: 0.9920 - val_loss: 0.0293
# Epoch 11/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9883 - loss: 0.0359 - val_accuracy: 0.9923 - val_loss: 0.0282
# Epoch 12/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9890 - loss: 0.0336 - val_accuracy: 0.9915 - val_loss: 0.0284
# Epoch 13/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9901 - loss: 0.0303 - val_accuracy: 0.9910 - val_loss: 0.0317
# Epoch 14/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9903 - loss: 0.0297 - val_accuracy: 0.9923 - val_loss: 0.0276
# Epoch 15/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9903 - loss: 0.0292 - val_accuracy: 0.9925 - val_loss: 0.0283
# Epoch 16/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9901 - loss: 0.0289 - val_accuracy: 0.9923 - val_loss: 0.0294
# Epoch 17/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9916 - loss: 0.0259 - val_accuracy: 0.9927 - val_loss: 0.0267
# Epoch 18/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9916 - loss: 0.0250 - val_accuracy: 0.9928 - val_loss: 0.0296
# Epoch 19/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9915 - loss: 0.0252 - val_accuracy: 0.9920 - val_loss: 0.0294
# Epoch 20/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9927 - loss: 0.0221 - val_accuracy: 0.9918 - val_loss: 0.0301
# Epoch 21/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9923 - loss: 0.0233 - val_accuracy: 0.9918 - val_loss: 0.0301
# Epoch 22/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9924 - loss: 0.0227 - val_accuracy: 0.9920 - val_loss: 0.0285
# Epoch 23/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9930 - loss: 0.0215 - val_accuracy: 0.9920 - val_loss: 0.0278
# Epoch 24/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9924 - loss: 0.0213 - val_accuracy: 0.9935 - val_loss: 0.0277
# Epoch 25/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9930 - loss: 0.0199 - val_accuracy: 0.9923 - val_loss: 0.0310
# Epoch 26/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9929 - loss: 0.0210 - val_accuracy: 0.9922 - val_loss: 0.0321
# Epoch 27/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9930 - loss: 0.0200 - val_accuracy: 0.9922 - val_loss: 0.0304
# Epoch 28/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9937 - loss: 0.0177 - val_accuracy: 0.9937 - val_loss: 0.0282
# Epoch 29/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9930 - loss: 0.0196 - val_accuracy: 0.9928 - val_loss: 0.0341
# Epoch 30/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9943 - loss: 0.0170 - val_accuracy: 0.9935 - val_loss: 0.0309
# Epoch 31/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9937 - loss: 0.0190 - val_accuracy: 0.9922 - val_loss: 0.0297
# Epoch 32/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9945 - loss: 0.0171 - val_accuracy: 0.9928 - val_loss: 0.0286
# Epoch 33/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9940 - loss: 0.0179 - val_accuracy: 0.9937 - val_loss: 0.0284
# Epoch 34/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9939 - loss: 0.0168 - val_accuracy: 0.9932 - val_loss: 0.0307
# Epoch 35/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9945 - loss: 0.0169 - val_accuracy: 0.9935 - val_loss: 0.0301
# Epoch 36/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9944 - loss: 0.0164 - val_accuracy: 0.9932 - val_loss: 0.0317
# Epoch 37/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9942 - loss: 0.0169 - val_accuracy: 0.9932 - val_loss: 0.0280
# Epoch 38/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9946 - loss: 0.0155 - val_accuracy: 0.9932 - val_loss: 0.0289
# Epoch 39/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9947 - loss: 0.0159 - val_accuracy: 0.9930 - val_loss: 0.0295
# Epoch 40/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9946 - loss: 0.0158 - val_accuracy: 0.9938 - val_loss: 0.0271
# Epoch 41/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9950 - loss: 0.0140 - val_accuracy: 0.9930 - val_loss: 0.0280
# Epoch 42/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9946 - loss: 0.0154 - val_accuracy: 0.9933 - val_loss: 0.0333
# Epoch 43/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9951 - loss: 0.0142 - val_accuracy: 0.9928 - val_loss: 0.0324
# Epoch 44/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9950 - loss: 0.0139 - val_accuracy: 0.9928 - val_loss: 0.0315
# Epoch 45/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9952 - loss: 0.0139 - val_accuracy: 0.9928 - val_loss: 0.0311
# Epoch 46/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9953 - loss: 0.0132 - val_accuracy: 0.9932 - val_loss: 0.0336
# Epoch 47/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9953 - loss: 0.0136 - val_accuracy: 0.9925 - val_loss: 0.0332
# Epoch 48/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9948 - loss: 0.0145 - val_accuracy: 0.9922 - val_loss: 0.0325
# Epoch 49/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9956 - loss: 0.0122 - val_accuracy: 0.9928 - val_loss: 0.0319
# Epoch 50/50
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9953 - loss: 0.0139 - val_accuracy: 0.9928 - val_loss: 0.0318

# %% [markdown]
# ### Save model

# %%
model.save('mnist_model.keras')

# %% [markdown]
# ## Evaluate the trained model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.021620240062475204
# Test accuracy: 0.9940999746322632

# %% [markdown]
# img = cv2.imread("test/1.png")
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# resized = cv2.resize(gray, (28, 28))
# resized = resized / 255
# resized = resized.reshape(1, 28, 28, 1)
